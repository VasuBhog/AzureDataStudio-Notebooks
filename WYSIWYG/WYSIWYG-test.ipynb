# %% [markdown]
# # WYSIWYG TESTING NOTEBOOK
#
# ## This Notebook Test requires the user to edit the different text cells with current WYSIWYG and ensure that it does not change the formatting

# %% [markdown]
# # **WYSIWYG Test Formatting**
# ### <u>Add some more text at any point of this text cell and exit the cell - ensure formatting does not change</u>
# **Span TEST**:
# \<StorageAccountType\><span style="background:red">Standard_GRS</span>\</StorageAccountType\>
# **Heading Test:**
# # \<H1test\>
# ## \<H2test\>
# ### \<H3test\>
# **Anchor Test**: [\\\\\<Link\_test\\\>](https://www.google.com/)
# **Bold Test**: **\<Bold test\>**
# **Italicize**: _\<Italicize test\>_
# **Underline**: <u>\<Underline\_test\></u>
# **Code**:
# ```
# \<Code_test\>
# ```
# **Lists:**
# - \<test\>
# 1. \<test\> This keeps all the tags
# **Tag inside text:** Even if they are not HTML tags awesome Mulitple HTML tags with non-HTML tag _\<test\>. see our FAQ and TSG to Notebook migration schedule._

# %% [markdown]
# # Table Tests
#
# Edit the table by modifying the text in one of the items in the table
#
# \- Expected Result Table does not add header or format differently when exiting the cell
#
# |  |  |  |
# | --- | --- | --- |
# | test | test | test |
# | test | test | test |
# | test | test | test |
# | test | test | test

# %% [markdown]
# # WYSIWYG text + image test:
#
# ## <u>Copy and Pasted this from [MS Doc](https://docs.microsoft.com/en-us/sql/azure-data-studio/quickstart-sql-server?view=sql-server-ver15#connect-to-a-sql-server).</u>
#
# <u>Expected Result: Text and Image are kept properly as shown on the website.</u>
#
# ## Connect to a SQL Server
#
# 1. Start Azure Data Studio.
#
# 2. The first time you run Azure Data Studio the Welcome page should open. If you don't see the Welcome page, select Help \> Welcome. Select New Connection to open the Connection pane:
#
#     [![New Connection Icon](https://github.com/MicrosoftDocs/sql-docs/raw/live/docs/azure-data-studio/media/quickstart-sql-server/new-connection-icon.png)](https://github.com/MicrosoftDocs/sql-docs/blob/live/docs/azure-data-studio/media/quickstart-sql-server/new-connection-icon.png)

# %% [markdown]
# # **Expected Results**
# ## **<u>Test 1 Expected Result:</u>**
# ![](data:image/png;base64,...)
# ## **<u>Test 2 Expected Result:</u>**
# ![](data:image/png;base64,...)
# ## **<u>Test 3 Expected Result:</u>**
# ![](data:image/png;base64,...)
